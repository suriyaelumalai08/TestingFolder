# %%
import cv2
import numpy as np

# %%
print('dd'.capitalize())
# Out:
# Dd

# %%
import cv2

cap = cv2.VideoCapture(0)

fourcc= cv2.VideoWriter_fourcc(*'XVID')

out = cv2.VideoWriter('output.avi',fourcc,20.0,(640,480))

print(cap.isOpened())

while (cap.isOpened()):
    ret,frame  = cap.read()
    if ret == True:

        # print(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        # print(cap.get(cv2.CAP_PROP_FRAME_WIDTH))

        # out.write(frame)

        cv2.imshow('frame',frame)

        if cv2.waitKey(1) & 0xFF == ord('s'):
            break
    else:
        break

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# True

# %%
cap = cv2.VideoCapture(0)
fourcc = cv2.VideoWriter_fourcc(*'MP4V')

out = cv2.VideoWriter(filename='myvideo.mp4',fourcc=fourcc,fps=20.0,frameSize=(640,480))

my_ima= list()


while cap.isOpened():

    ret,frame = cap.read()
    if ret == True:
        cv2.imshow('recvideo',frame)
        # print(frame)
        out.write(frame)
        key = cv2.waitKey(1) & 0xFF
        if key == 27:  
            break
        elif key == 13:  
            cv2.imwrite(filename='myimage.png',img=frame)
            my_ima.append(frame)
            print('successfuly image was save')
    else:
        break
cap.release()
out.release()
cv2.destroyAllWindows()

# %%
image_array=my_ima[0]

cv2.imshow('frame',image_array)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Load the saved image 'myimage.png' into an array
my_img = cv2.imread('myimage.png')

# Display the image using imshow
cv2.imshow('myimage', my_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[17], line 2
#       1 # print(my_ima)
# ----> 2 b=cv2.imread(my_ima,np.uint8)
#       3 cv2.imshow('myimagge',b)
#       5 cv2.waitKey(0)
#
# error: OpenCV(4.13.0) :-1: error: (-5:Bad argument) in function 'imread'
# > Overload resolution failed:
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object
# >  - Expected 'filename' to be a str or path-like object

# %%
import datetime

# %%
cap = cv2.VideoCapture(0)

# 3 is repersent width and 4 is repersent height

cap.set(3,1280)
cap.set(4,720)

while (cap.isOpened()):
    ret,frame = cap.read()

    font  = cv2.FONT_HERSHEY_SIMPLEX
    width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
    height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
    times = datetime.datetime.now()

    text = 'width:'+str(width)+' height:'+str(height)+' time:'+str(times)
    frame  = cv2.putText(frame,text,(10,50),font,1,(100,200,150),2,cv2.LINE_AA)

    cv2.imshow('frame',frame)

    if cv2.waitKey(1) == ord('s'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
import cv2

# Use raw string (VERY IMPORTANT for Windows paths)
video_path = r"D:\python\python\testing\myvideo.mp4"

# Open video file
cap = cv2.VideoCapture(video_path)

# Check if file opened successfully
if not cap.isOpened():
    print("Error: Cannot open video file")
    exit()

while True:
    ret, frame = cap.read()

    # If frame not read properly → break


    # Show frame
    cv2.imshow("Video", frame)

    # Press 'q' to exit
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break


# Release resources
cap.release()
cv2.destroyAllWindows()

# %%
import os

path = os.path()
if path:
    print(True)
else:
    print(False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 import os
# ----> 3 path = os.path("E:\Backup\Snapchat-1294799493.mp4")
#       4 if path:
#       5     print(True)
#
# TypeError: 'module' object is not callable

# %%
import os

file_path = r"E:\Backup\Snapchat-1294799493.mp4"

if os.path.exists(file_path):
    with open(file_path, 'rb') as f:  # ✅ binary mode
        data = f.read()
        print("File size:", len(data), "bytes")
else:
    print("File not found")
# Out:
# File size: 9355952 bytes

# %%
import cv2
import pygame
from moviepy import VideoFileClip

video_path = r"E:\Backup\Snapchat-1294799493.mp4"

# Extract audio from video
clip = VideoFileClip(video_path)
clip.audio.write_audiofile("temp_audio.mp3")



# Open video
cap = cv2.VideoCapture(video_path)

cap.set(3,720)
cap.set(4,480)

fps = cap.get(cv2.CAP_PROP_FPS)
delay = int(1000 / fps)

# Initialize audio
pygame.mixer.init()
pygame.mixer.music.load("temp_audio.mp3")
pygame.mixer.music.play()

while True:
    ret, frame = cap.read()

    if not ret:
        break

    cv2.imshow("Video", frame)

    if cv2.waitKey(delay) & 0xFF == ord('q'):
        break

pygame.mixer.music.stop()

cap.release()

cv2.destroyAllWindows()
# Out:
# c:\Users\EATSK\AppData\Local\Programs\Python\Python311\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# MoviePy - Writing audio in temp_audio.mp3
# MoviePy - Done.

# %%
pygame.mixer.music.load("temp_audio.mp3")
pygame.mixer.music.play()
pygame.mixer.music.stop()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
v=cv2.VideoCapture(file_path)

while True:

    ret,frame =  v.read()
    if ret:

        cv2.imshow('frame',frame)

        if cv2.waitKey(20) & 0xFF == ord('a'):
            break
    else:
        break
v.release()
cv2.destroyAllWindows()

# %%
# Create a simple test image (no file needed)
img = np.zeros((300, 400, 3), dtype=np.uint8)  # black canvas
cv2.putText(img, "cv2 works!", (80, 160), cv2.FONT_HERSHEY_SIMPLEX, 2, (0, 255, 0), 3)
cv2.rectangle(img, (20, 20), (380, 280), (255, 100, 0), 2)

# Display it
cv2.imshow("Test", img)
cv2.waitKey(0)       # wait for any key press
cv2.destroyAllWindows()

# Save it
print("Saved test_output.png")
# Out:
# Saved test_output.png

# %%
import cv2
import numpy as np

def click_event(event, x, y, flags, userdata):
    if event==cv2.EVENT_LBUTTONDOWN:
        font = cv2.FONT_HERSHEY_SIMPLEX
        text = str(x)+','+str(y)
        cv2.putText(img,text,(x,y),font,.5,(0,255,0),2)
        cv2.imshow('image',img)

img = np.zeros((512,521,3),np.uint8)
# print(img)
cv2.imshow('image',img)

cv2.setMouseCallback('image',click_event)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
def click_event2(event,x,y,flags,userdata):
    if event == cv2.EVENT_LBUTTONDOWN:
        red = img[x,y,2]
        green = img[x,y,1]
        blue = img[x,y,0]
        cv2.circle(img,(x,y),3,(0,0,255),-1)

        mycolor = np.zeros((512,512,3),np.uint8)
        mycolor[:]=[blue,green,red]
        cv2.imshow('your choose color',mycolor)

# img = np.zeros((512,512,3),np.uint8)

img =  cv2.imread('cat1.jpg')
cv2.imshow('image',img) 

cv2.setMouseCallback('image',click_event2)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread('cat1.jpg')
if img is None:
    print("Error: Image not found or could not be loaded.")
else:
    cv2.imshow('image', img)
    cv2.setMouseCallback('image', click_event2)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
img = cv2.imread('car.jpeg')

part = img[100:170,100:170]

img[130:200,100:170]=part
cv2.imshow('image',img)
# cv2.imshow('image',part)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
print(img.shape)
print(img.size)
print(img.dtype)
r,g,b = cv2.split(img)
print(r,g,b)
# Out:
# (220, 392, 3)
# 258720
# uint8
# [[234 231 229 ... 207 210 213]
#  [228 226 223 ... 206 209 212]
#  [226 223 220 ... 204 207 210]
#  ...
#  [120 117 115 ... 103 107 115]
#  [122 118 114 ... 102 106 113]
#  [125 120 114 ... 102 105 112]] [[233 230 228 ... 192 195 198]
#  [227 225 222 ... 191 194 197]
#  [225 222 219 ... 190 193 196]
#  ...
#  [122 119 117 ... 107 111 119]
#  [124 120 116 ... 106 110 117]
#  [127 122 116 ... 106 109 116]] [[243 240 238 ... 196 199 202]
#  [237 235 232 ... 195 198 201]
#  [235 232 229 ... 194 197 200]
#  ...
#  [133 130 128 ... 118 122 130]
#  [135 131 127 ... 117 121 128]
#  [138 133 127 ... 117 120 127]]

# %%
img1 = cv2.imread('car.jpeg')
img2 = cv2.imread('cat2.jpg')

img1 = cv2.resize(img1,(200,200))
img2 = cv2.resize(img,(200,200))

# out = cv2.addWeighted(img1, .3,img2,.02,0)
out = cv2.add(img1,img2)
cv2.imshow('output',out)
# cv2.imshow('first image',img1)
# cv2.imshow('second',img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.imread('blackwithwhite.png')

img = cv2.resize(img,(200,200))
img2 = np.zeros((200,200,3),np.uint8)
img2 = cv2.rectangle(img2, (0, 0), (100, 100), (0,0,0), -1)

bit_and = cv2.bitwise_and(img,img2)

bit_or = cv2.bitwise_or(img,img2)

bit_not  = cv2.bitwise_not(img,img2)

bit_xor = cv2.bitwise_xor(img,img2)
# cv2.imshow('image',bit_xor)
cv2.imshow('imageg',img)

# cv2.imshow('image',img2)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = np.zeros((300,512,3),np.uint8)

def noteif(x):
    print(x)

cv2.namedWindow('Image')

cv2.createTrackbar('B','Image',0,255,noteif)
cv2.createTrackbar('G','Image',0,255,noteif)
cv2.createTrackbar('R','Image',0,255,noteif)

while True:
    # Get trackbar positions BEFORE displaying
    b=cv2.getTrackbarPos('B','Image')
    g=cv2.getTrackbarPos('G','Image')
    r=cv2.getTrackbarPos('R','Image')
    
    # Update image with current trackbar values
    img[:]=[b,g,r]
    
    # Display and wait for input
    cv2.imshow('image',img)

    if cv2.waitKey(1) & 0xFF == ord('s'):
        break

cv2.destroyAllWindows()

# %%
img =  cv2.imread('car.jpeg')

w,h = img.shape[:2]

print(w,h)

ratio = 180/w

dim = (180 , int(h * ratio))

rotational = cv2.resize(img,dim)

cv2.imshow('image',rotational)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 220 392

# %%
output = img.copy()

rectangle = cv2.rectangle(output,(170,250),(200,280),(0,0,0),-1)

cv2.imshow('rectangle',rectangle)

cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
def noteif(x):
    print(x)

cv2.namedWindow('image')

cv2.createTrackbar('cp','image',10,400,noteif)
switch = 'color/gray'
cv2.createTrackbar(switch,'image',0,1,noteif)

while True:
    img = cv2.imread('car.jpeg')
    pos = cv2.getTrackbarPos('cp','image')
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(img,str(pos),(50,150),font,4,(0,0,255))

    if cv2.waitKey(0)&0xFF == 27:
        break

    s = cv2.getTrackbarPos(switch,'image')

    if s==0:
        pass
    else:
        img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    img=cv2.imshow('image',img)
cv2.destroyAllWindows()
# Out:
# 10

# %%
img = cv2.imread('car.jpeg',cv2.IMREAD_COLOR)

copy_image = img.copy()

rectangle = cv2.rectangle(copy_image,(150,10),(300,100),(255,0,0),5)
font = cv2.FONT_HERSHEY_SIMPLEX

strs = '50,100'

cv2.putText(rectangle,strs,(20,50),font,2,(0,255,0))

cv2.imshow('image',rectangle)

cv2.waitKey(0)
cv2.destroyAllWindows()
# print(copy_image.shape[:2])

# %%
def noteif(x):
    print(x)

while True:
    img = cv2.imread('balls.jpg')

    img = cv2.resize(img,(300,300))

    hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)

    l_b = np.array([110,50,50])

    u_b = np.array([130,255,255])

    l_r = np.array([0,120,70])

    u_r = np.array([10,255,255])

    l_g = np.array([40,50,50])

    u_g = np.array([80,255,255])

    m1_b = np.array([0,120,80])
    m2_b = np.array([10,255,255])

    n1_r =np.array([255,255,255])
    n2_r = np.array([255,255,255])

    mask = cv2.inRange(hsv,l_b,u_b)

    res = cv2.bitwise_and(img,img,mask=mask)

    cv2.imshow('image',img)
    cv2.imshow('mask',mask)
    cv2.imshow('res',res)

    if cv2.waitKey(0)==ord('s'):
        break
cv2.destroyAllWindows()

# %%
def noteif(x):
    pass


cap = cv2.VideoCapture(0)

cv2.namedWindow('colorimage')

cv2.createTrackbar('lh','colorimage',0,255,noteif)
cv2.createTrackbar('ls','colorimage',0,255,noteif)
cv2.createTrackbar('lv','colorimage',0,255,noteif)
cv2.createTrackbar('uh','colorimage',255,255,noteif)
cv2.createTrackbar('us','colorimage',255,255,noteif)
cv2.createTrackbar('uv','colorimage',255,255,noteif)



while True:
    # img = cv2.imread('balls.jpg')

    _,img = cap.read()
    # img = cv2.resize(img,(400,400))

    hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)

    #hue saturation and values

    l_h = cv2.getTrackbarPos('lh','colorimage')
    l_s = cv2.getTrackbarPos('ls','colorimage')
    l_v = cv2.getTrackbarPos('lv','colorimage')

    u_h = cv2.getTrackbarPos('uh','colorimage')
    u_s = cv2.getTrackbarPos('us','colorimage')
    u_v = cv2.getTrackbarPos('uv','colorimage')

   

    l_b = np.array([l_h,l_s,l_v])

    u_b = np.array([u_h,u_s,u_v])

    mask = cv2.inRange(hsv,l_b,u_b)

    res = cv2.bitwise_and(img,img,mask=mask)

    cv2.imshow('image',img)
    cv2.imshow('mask',mask)
    cv2.imshow('res',res)

    if cv2.waitKey(1) & 0xFF == ord('s'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
while True:
    img = cv2.imread('car.jpeg')
    img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    # _,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
    # _,th2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
    _,th3 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
    _,th4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)

    cv2.imshow('image',img)
    cv2.imshow('th1',th4)
    # cv2.imshow('th2',th2)
    # cv2.imshow('th3',th3)
    # cv2.imshow('th4',th4)
    if cv2.waitKey(0) & 0xFF == ord('s'):
        break
cv2.destroyAllWindows()

# %%
img = cv2.imread('car.jpeg')

cv2.imshow('c',img)

cv2.waitKey(0)

cv2.destroyAllWindows()

import cv2
import matplotlib.pyplot as plt

img = cv2.imread('car.jpeg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = cv2.imread('sudo.jpeg',1)

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

adt = cv2.adaptiveThreshold(gray,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,2)

cv2.imshow('image',img)
cv2.imshow('adt',adt)

cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
import cv2

# Open the webcam
cap = cv2.VideoCapture(0)

# Capture one frame
ret, frame = cap.read()

if ret:
    # Save the frame as a PNG file
    cv2.imwrite('myimage.png', frame)
    print("Frame captured and saved as 'myimage.png'")
else:
    print("Failed to capture frame from webcam")

# Release the webcam
cap.release()
# Out:
# Frame captured and saved as 'myimage.png'

# %%
import cv2
import numpy as np

# Example: Create an image array (replace this with your actual array)
# Assuming your image array is something like this (BGR format, uint8)
image_array = np.zeros((300, 400, 3), dtype=np.uint8)  # Black image
# Or load from file: image_array = cv2.imread('your_image.jpg')

# If your array is not uint8, convert it
# image_array = (image_array * 255).astype(np.uint8)  # Example for float to uint8

# Display the image
cv2.imshow('Image from Array', image_array)

# Wait for a key press and close the window
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
a=np.ones((3,3,3),dtype=np.uint8)
b = np.arange(2,5)
print(a+b)
# Out:
# [[[3 4 5]
#   [3 4 5]
#   [3 4 5]]
#
#  [[3 4 5]
#   [3 4 5]
#   [3 4 5]]
#
#  [[3 4 5]
#   [3 4 5]
#   [3 4 5]]]

# %%
import matplotlib.pyplot as plt

img = cv2.imread('blackwithwhite.png')

_,th1 = cv2.threshold(img,130,255,cv2.THRESH_BINARY)
_,th2 = cv2.threshold(img,130,255,cv2.THRESH_BINARY_INV)
_,th3 = cv2.threshold(img,130,255,cv2.THRESH_TOZERO)
_,th4 = cv2.threshold(img,130,255,cv2.THRESH_TRUNC)
_,th5 = cv2.threshold(img,130,255,cv2.THRESH_TOZERO_INV)


name = ['original','BINARY','BINARY_INV',"TOZERO",'TRUNC','TOZERO_INV']

images = [img,th1,th2,th3,th4,th5]

for i in range(6):
    plt.subplot(2,3,i+1)
    plt.imshow(images[i],'gray')
    plt.title(name[i])
    plt.xticks([])
    plt.yticks([])

plt.show()


# cv2.imshow('alsdjl',img)

# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
from ultralytics import YOLO
import numpy as np
import cv2

# %%
def object_detected():

    model = YOLO('yolov8n.pt')

    img = cv2.imread('obj.webp')
    org_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

    result = model(org_img)[0]

    annotation_img = org_img.copy()

    np.random.seed(42)
    colors = np.random.randint(0,255,size=(100,3),dtype=np.uint8)

    class_name = {}

    boxes = result.boxes

    return boxes, result.names, annotation_img, colors




boxes, class_names, annotated_image, colors = object_detected()



print(colors[0])




cv2.imshow('img',annotated_image)

cv2.waitKey(2000)
cv2.destroyAllWindows()
# Out:
# 0: 448x640 1 person, 6 cars, 6 traffic lights, 140.5ms
# Speed: 8.3ms preprocess, 140.5ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# [102 220 225]

# %%
img = np.zeros((300,500,3),np.uint8)
img_cor = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
cv2.imshow('img',img)
cv2.imshow('images',img_cor)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
from ultralytics import YOLO
import matplotlib.pyplot as plt

def detect_objects(image_path):
    """
    Detect objects in an image using YOLOv8.
    
    Args:
        image_path: Path to the input image
    
    Returns:
        Detected objects and class labels.
    """
    # Load YOLO model
    model = YOLO('yolov8n.pt')  # Load the model
    
    # Read image
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # Perform detection
    results = model(image_rgb)[0]
    
    # Create a copy of the image for drawing
    annotated_image = image_rgb.copy()
    
    # Generate random colors for classes
    np.random.seed(42)  # For consistent colors
    colors = np.random.randint(0, 255, size=(100, 3), dtype=np.uint8)
    
    # To hold class names and their corresponding colors
    class_labels = {}
    
    # Process detections
    boxes = results.boxes
    
    # print(boxes, results.names, annotated_image, colors)
    return boxes, results.names, annotated_image, colors

def show_results(image_path, confidence_threshold):
    """
    Show original image and detection results side by side.

    Args:
        image_path: Path to the input image
        confidence_threshold: Minimum confidence score for detections
    """
    # Read original image
    original_image = cv2.imread(image_path)
    original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)
    
    # Get detection results
    boxes, class_names, annotated_image, colors = detect_objects(image_path)
    
    # Process each detected object and apply confidence threshold filtering
    class_labels = {}
    for box in boxes:
        # Get box coordinates
        x1, y1, x2, y2 = map(int, box.xyxyn[0])
        
        # Get confidence score
        confidence = float(box.conf[0])
        
        # Only show detections above confidence threshold
        if confidence > confidence_threshold:
            # Get class id and name
            class_id = int(box.cls[0])
            class_name = class_names[class_id]
            
            # Get color for this class
            color = colors[class_id % len(colors)].tolist()
            
            # Draw bounding box
            cv2.rectangle(annotated_image, (x1, y1), (x2, y2), color, 2)
            
            # Store class name and color for legend
            class_labels[class_name] = color


    print(class_labels)
    # Create figure
    plt.figure(figsize=(15, 7))
    
    # Show original image
    plt.subplot(1, 2, 1)
    plt.title('Original Image')
    plt.imshow(original_image)
    plt.axis('off')
    cv2.imshow('img',annotated_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    # Show detection results
    plt.subplot(1, 2, 2)
    plt.title('Detected Objects')
    plt.imshow(annotated_image)
    plt.axis('off')

    # Create legend
    legend_handles = []
    for class_name, color in class_labels.items():
        normalized_color = np.array(color) / 255.0  # Normalize the color
        legend_handles.append(plt.Line2D([0], [0], marker='o', color='w', label=class_name,
                                           markerfacecolor=normalized_color, markersize=10))

    plt.legend(handles=legend_handles, loc='upper right', title='Classes')

    plt.tight_layout()
    plt.show()

# Example usage:
show_results('obj.webp', confidence_threshold=0.2)
# Out:
# 0: 448x640 1 person, 6 cars, 6 traffic lights, 205.4ms
# Speed: 3.6ms preprocess, 205.4ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
# {'car': [234, 203, 92], 'person': [102, 220, 225], 'traffic light': [153, 20, 44]}

# %%
import cv2

model = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

cam = cv2.VideoCapture(0)

while True:
    ret,frame = cam.read()

    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)

    obj = model.detectMultiScale(gray)

    for (x,y,w,h) in obj:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,0,255),2)
    cv2.imshow('frame',frame)

    key = cv2.waitKey(1)

    if key==ord('s'):
        break
cam.release()
cv2.destroyAllWindows()
