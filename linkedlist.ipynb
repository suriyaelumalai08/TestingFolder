# %%
print('hi')
# Out:
# hi

# %%
class node:
    def __int__(self,data):
        self.data=data
        self.pointer=None
class linkedlist:
    def __int__(self):
        self.head=None
    def add(self,data):
        new_node=node(data)
        if self.head is None:
            self.head=new_node
        else:
            cur=self.head
            while cur.pointer is not None:
                cur=cur.pointer
            cur.pointer=new_node
    def show(self):
        cur=self.head
        while cur is not None:
            print(cur.data,end=" ")
            cur=cur.pointer

# %%
ll=linkedlist()
ll.add(10)
ll.add(20)
ll.add(30)
ll.add(40)
ll.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 ll=linkedlist()
# ----> 2 ll.add(10)
#       3 ll.add(20)
#       4 ll.add(30)
#
# Cell In[11], line 9, in linkedlist.add(self, data)
#       8 def add(self,data):
# ----> 9     new_node=node(data)
#      10     if self.head is None:
#      11         self.head=new_node
#
# TypeError: node() takes no arguments

# %%
class n:
    def __init__(self,data):
        self.data=data
        self.pointer=None

# %%
class linkedlist:
    def __init__(self):
        self.head=None
    def add(self,data):
        new_none=n(data)
        if self.head is None:
            self.head=new_none
        else:
            cur=self.head
            while cur.pointer is not None:
                cur=cur.pointer
            cur.pointer=new_none
    def show(self):
        cur=self.head
        while cur is not None:
            print(cur.data,end=" ")
            cur=cur.pointer
        print()
    def remove(self,data):
        if self.head is not None:
            if self.head.data==data:
                self.head=self.head.pointer
            else:
                cur=self.head
                while cur is not None and cur.pointer.data!=data:
                    cur=cur.pointer
                if cur.pointer is not None:
                    cur.pointer=cur.pointer.pointer
                else:
                    print(f"{data} is not in linked list") 
        else:
            print('linked list is empty')
    

    def update(self,pos,data):
        new_node=n(data)
        if self.head is not None:
            if self.head.data ==pos:
                new_node.pointer=self.head
                self.head=new_node
                return
            else:
                cur=self.head
                try:
                    while cur is not None and cur.pointer.data!=pos:
                        cur=cur.pointer
                        new_cur=cur.pointer
                        # print(new_cur)
                except Exception as e:
                    print(f'{e} error.')
                    
                if cur.pointer is not None:
                    cur.pointer=new_node
                    new_node.pointer=new_cur
                
                # print(cur.pointer)
                # print(new_node.data)
        else:
            print('linked list is empty.')

# %%
ll=linkedlist()
ll.add(10)
ll.add(20)
ll.add(30)
ll.add(40)
ll.show()
# ll.remove(30)
ll.update(50,45)
# ll.update(50,45)
ll.show()
# Out:
# 10 20 30 40
# 'NoneType' object has no attribute 'data' error.
# 10 20 30 40

# %% [markdown]
# Stack

# %%
stack=[]
exp="(()())"
count=0
for i in exp:
    if i =="(":
        stack.append(i)
        # print(stack)
    elif i == ")":
        stack.pop()
        # print(stack)
    

if not stack:
    print('balance')
else:
    print('not balance')
# Out:
# balance

# %%
def recursion(n):
    print(n)
    if n==1:
        return 1
    return n*recursion(n-1)

print(recursion(4))
# Out:
# 4
# 3
# 2
# 1
# 24

# %%
class root_node:
    def __int__(self,data):
        self.base_root=data
        self.left_node=None
        self.right_node=None

# %%
class tree:
    def __init__(self):
        self.root=None
    def add(self,data):
        new_root=root_node(data)
        print(new_root)

# %%
new_data=root_node(10)
print(new_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 new_data=root_node(10)
#       2 print(new_data)
#
# TypeError: root_node() takes no arguments

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.left=None
        self.right=None

# %%
def display():
    cur=

# %%
class root:
    def __init__(self):
        self.head=None
    # def add(self,data,left=False,right=False):
    #     new_root=node(data)
    #     if self.head is None:
    #         self.head=new_root
    #         print(self.head.data)
    #     else:
    #         cur=self.head
    #         if left:
    #             while cur.left is not None:
    #                 cur=cur.left
    #             cur.left=new_root
    #         else:
    #             cur=self.head
    #             while cur.right is not None:
    #                 cur=cur.right
    #             cur.right=new_root

# %%
r=root()

r.add(10)
# Out:
# 10

# %%
r=root(10)
r.left=root(20)
r.right=root(30)
r.left.left=root(24)
r.left.right=root(28)

# %%
root1=root(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 root1=root(10)
#
# TypeError: 'root' object is not callable

# %%
class head:
    def __init__(self):
        self.root=None
    def

# %%
print(r.data)
print(r)
# Out:
# 10
# ...
